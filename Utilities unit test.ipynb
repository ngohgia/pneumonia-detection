# %%
from visualization import *
import pandas as pd
import os

DATA_DIR = '../data'

train_box_data_path = os.path.join(DATA_DIR, 'train.csv')
df_train = pd.read_csv(train_box_data_path)

train_pid = df_train['patientId'].sample(1).values[0]
display_patient_image(df_train, train_pid, sample='train')
